# %%
from positionsplanung import expositionsklassen as exp

# %%
exp = exp.Expositionsklassen.from_list(["XC3", "XF1", "XA2", "WF"])

print(exp)
print(exp.aktive_klassen())
print(exp.to_dict())
print(exp.to_df())
# Out:
# Expositionsklassen(XC3, XF1, XA2, WF)
# ['XC3', 'XF1', 'XA2', 'WF']
# {'X0': False, 'XC': 3, 'XD': None, 'XS': None, 'XF': 1, 'XM': None, 'XA': 2, 'feuchteklasse': 'WF'}
#       X0  XC    XD    XS  XF    XM  XA feuchteklasse
# 0  False   3  None  None   1  None   2            WF
